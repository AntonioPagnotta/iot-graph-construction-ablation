# %% [markdown]
# # Global Configuration

# %%
# 1. Define your feature groups
identifiers = ['Flow ID', 'Src IP', 'Dst IP', 'Timestamp', 'Label', 'Attack']
network_features = ['Src Port', 'Dst Port', 'Protocol', 'Flow Duration']
context_features = ['Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Flow Byts/s', 'Flow Pkts/s', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts', 'Subflow Bwd Byts', 'Fwd Act Data Pkts', 'Down/Up Ratio', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min']
knowledge_features = ['Fwd Pkt Len Max', 'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg', 'Fwd Byts/b Avg', 'Fwd Pkts/b Avg', 'Fwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Pkts/b Avg', 'Bwd Blk Rate Avg', 'Init Fwd Win Byts', 'Init Bwd Win Byts', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Seg Size Min', 'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std', 'Pkt Len Var']

# Specify the features to keep
features_to_keep = [
    #selected features
]
# 2. SELECT CONFIGURATION HERE
CONFIG = 'A'  # Change to 'A', 'B', 'C', or 'D'

# 3. Apply Configuration rules dynamically
if CONFIG == 'A':
    features_to_keep = identifiers + network_features
    active_edges = {'network'}
elif CONFIG == 'B':
    features_to_keep = identifiers + network_features + context_features
    active_edges = {'network', 'context'}
elif CONFIG == 'C':
    features_to_keep = identifiers + network_features + knowledge_features
    active_edges = {'network', 'knowledge'}
elif CONFIG == 'D':
    features_to_keep = identifiers + network_features + context_features + knowledge_features
    active_edges = {'network', 'context', 'knowledge'}

# %% [markdown]
# # Create the test datastracture for 3 edges

# %%
import pandas as pd

# Load your dataset
data = pd.read_csv('test_data.csv')  # Replace 'test_data.csv' with your actual file name

# Keep only the specified features
filtered_data = data[features_to_keep].copy()

# Convert 'Timestamp' to datetime
filtered_data['Timestamp'] = pd.to_datetime(filtered_data['Timestamp'])

# Order the data by 'Timestamp'
filtered_data = filtered_data.sort_values(by='Timestamp')

# Save the temporally ordered data to a new file
filtered_data.to_csv('filtered_test_3edge.csv', index=False)

print("Filtered and temporally ordered data saved to 'filtered_test_3edge.csv'.")
# Out:
# /var/folders/vw/nm4pm2012rj1j5k7yc6x23bw0000gn/T/ipykernel_86747/1873209483.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   filtered_data['Timestamp'] = pd.to_datetime(filtered_data['Timestamp'])
# Filtered and temporally ordered data saved to 'filtered_test_3edge.csv'.

# %%
#check for inside of csv (just for test, no need for run)
import pandas as pd

# Load the CSV file
file_path = "filtered_test_3edge.csv"  # Replace with your actual file path
df = pd.read_csv(file_path)

# Check if the label column contains '1'
label_column = 'Label'  # Replace with the actual label column name if different
if label_column in df.columns:
    label_distribution = df[label_column].value_counts()
    print("Label Distribution:")
    print(label_distribution)

    if 1 in label_distribution.index:
        print("The CSV contains label '1'.")
    else:
        print("The CSV does NOT contain label '1'.")
else:
    print(f"'{label_column}' column not found in the CSV.")
# Out:
# Label Distribution:
# Label
# 1    113461
# 0    100610
# Name: count, dtype: int64
# The CSV contains label '1'.

# %% [markdown]
# # created hourly graph with 3 edges from test dataset

# %%
import pandas as pd
import networkx as nx
import os

def create_test_graphs_edge_labels(df, output_dir):
    """
    Split the DataFrame into hourly slices and create graphs for each slice.
    Each edge gets a valid label (e.g., 0 or 1) read from the DataFrame.
    
    Parameters:
        df (pd.DataFrame): The input DataFrame with temporal data.
        output_dir (str): Directory to save the graphs.
    """
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Group the DataFrame into hourly slices using the datetime index.
    # (Assumes the DataFrame index is already a DateTimeIndex)
    time_slices = [g for _, g in df.groupby(pd.Grouper(freq='h'))]
    
    for slice_index, slice_df in enumerate(time_slices):
        if slice_df.empty:
            continue

        # Print value counts of the 'Label' column in this time-slice.
        print(f"Hour {slice_index}:")
        print(slice_df['Label'].value_counts())
        
        # Create a MultiDiGraph for this time-slice.
        G = nx.MultiDiGraph()

        for _, row in slice_df.iterrows():
            src_ip = row['Src IP']
            dst_ip = row['Dst IP']
            
            # Convert the label to an int (if missing or invalid, you can decide a fallback; here we assume it is valid)
            try:
                label = int(row['Label'])
            except Exception as e:
                print(f"Skipping row due to invalid label: {row['Label']}; error: {e}")
                continue

            if pd.isna(src_ip) or pd.isna(dst_ip):
                continue

            # Add nodes if not already present.
            if not G.has_node(src_ip):
                G.add_node(src_ip)
            if not G.has_node(dst_ip):
                G.add_node(dst_ip)

            # Add edges conditionally based on the active config
            # 1. Network Edge
            if 'network' in active_edges:
                net_attrs = {feat: row[feat] for feat in network_features if feat in row}
                G.add_edge(src_ip, dst_ip, key='network', label=label, interaction='network_communication', **net_attrs)

            # 2. Context Edge
            if 'context' in active_edges:
                ctx_attrs = {feat: row[feat] for feat in context_features if feat in row}
                G.add_edge(src_ip, dst_ip, key='context', label=label, interaction='context', **ctx_attrs)

            # 3. Knowledge Edge
            if 'knowledge' in active_edges:
                knw_attrs = {feat: row[feat] for feat in knowledge_features if feat in row}
                G.add_edge(src_ip, dst_ip, key='knowledge', label=label, interaction='knowledge', **knw_attrs)

        # Save the graph as a .gpickle file.
        graph_path = os.path.join(output_dir, f"test_graph_hour_{slice_index}.gpickle")
        nx.write_gpickle(G, graph_path)
        print(f"Test graph for hour {slice_index} saved to {graph_path}")

# Usage Example for graph creation
if __name__ == "__main__":
    # Read CSV and prepare DataFrame.
    df_test = pd.read_csv('filtered_test_3edge.csv')
    df_test['Timestamp'] = pd.to_datetime(df_test['Timestamp'])
    # Set Timestamp as index and sort (required for grouping by hour)
    df_test = df_test.set_index('Timestamp').sort_index()

    output_test_dir = "3ed_tes_h_graphs"
    create_test_graphs_edge_labels(df_test, output_test_dir)
# Out:
# Hour 0:
# Label
# 0    3
# Name: count, dtype: int64
# Test graph for hour 0 saved to 3ed_tes_h_graphs/test_graph_hour_0.gpickle
# Hour 1:
# Label
# 0    4
# Name: count, dtype: int64
# Test graph for hour 1 saved to 3ed_tes_h_graphs/test_graph_hour_1.gpickle
# Hour 2:
# Label
# 0    5
# Name: count, dtype: int64
# Test graph for hour 2 saved to 3ed_tes_h_graphs/test_graph_hour_2.gpickle
# Hour 3:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 3 saved to 3ed_tes_h_graphs/test_graph_hour_3.gpickle
# Hour 652:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 652 saved to 3ed_tes_h_graphs/test_graph_hour_652.gpickle
# Hour 653:
# Label
# 0    4
# Name: count, dtype: int64
# Test graph for hour 653 saved to 3ed_tes_h_graphs/test_graph_hour_653.gpickle
# Hour 654:
# Label
# 0    9
# Name: count, dtype: int64
# Test graph for hour 654 saved to 3ed_tes_h_graphs/test_graph_hour_654.gpickle
# Hour 655:
# Label
# 0    2
# Name: count, dtype: int64
# Test graph for hour 655 saved to 3ed_tes_h_graphs/test_graph_hour_655.gpickle
# Hour 656:
# Label
# 0    3
# Name: count, dtype: int64
# Test graph for hour 656 saved to 3ed_tes_h_graphs/test_graph_hour_656.gpickle
# Hour 657:
# Label
# 0    2
# Name: count, dtype: int64
# Test graph for hour 657 saved to 3ed_tes_h_graphs/test_graph_hour_657.gpickle
# Hour 658:
# Label
# 0    7
# Name: count, dtype: int64
# Test graph for hour 658 saved to 3ed_tes_h_graphs/test_graph_hour_658.gpickle
# Hour 670:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 670 saved to 3ed_tes_h_graphs/test_graph_hour_670.gpickle
# Hour 671:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 671 saved to 3ed_tes_h_graphs/test_graph_hour_671.gpickle
# Hour 672:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 672 saved to 3ed_tes_h_graphs/test_graph_hour_672.gpickle
# Hour 673:
# Label
# 0    3
# Name: count, dtype: int64
# Test graph for hour 673 saved to 3ed_tes_h_graphs/test_graph_hour_673.gpickle
# Hour 674:
# Label
# 0    3
# Name: count, dtype: int64
# Test graph for hour 674 saved to 3ed_tes_h_graphs/test_graph_hour_674.gpickle
# Hour 675:
# Label
# 0    2
# Name: count, dtype: int64
# Test graph for hour 675 saved to 3ed_tes_h_graphs/test_graph_hour_675.gpickle
# Hour 1397:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1397 saved to 3ed_tes_h_graphs/test_graph_hour_1397.gpickle
# Hour 1398:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1398 saved to 3ed_tes_h_graphs/test_graph_hour_1398.gpickle
# Hour 1399:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1399 saved to 3ed_tes_h_graphs/test_graph_hour_1399.gpickle
# Hour 1400:
# Label
# 0    2
# Name: count, dtype: int64
# Test graph for hour 1400 saved to 3ed_tes_h_graphs/test_graph_hour_1400.gpickle
# Hour 1401:
# Label
# 0    2
# Name: count, dtype: int64
# Test graph for hour 1401 saved to 3ed_tes_h_graphs/test_graph_hour_1401.gpickle
# Hour 1402:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1402 saved to 3ed_tes_h_graphs/test_graph_hour_1402.gpickle
# Hour 1404:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1404 saved to 3ed_tes_h_graphs/test_graph_hour_1404.gpickle
# Hour 1405:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1405 saved to 3ed_tes_h_graphs/test_graph_hour_1405.gpickle
# Hour 1406:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1406 saved to 3ed_tes_h_graphs/test_graph_hour_1406.gpickle
# Hour 1407:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1407 saved to 3ed_tes_h_graphs/test_graph_hour_1407.gpickle
# Hour 1410:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1410 saved to 3ed_tes_h_graphs/test_graph_hour_1410.gpickle
# Hour 1411:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1411 saved to 3ed_tes_h_graphs/test_graph_hour_1411.gpickle
# Hour 1412:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1412 saved to 3ed_tes_h_graphs/test_graph_hour_1412.gpickle
# Hour 1874:
# Label
# 0    9
# Name: count, dtype: int64
# Test graph for hour 1874 saved to 3ed_tes_h_graphs/test_graph_hour_1874.gpickle
# Hour 1875:
# Label
# 0    818
# Name: count, dtype: int64
# Test graph for hour 1875 saved to 3ed_tes_h_graphs/test_graph_hour_1875.gpickle
# Hour 1876:
# Label
# 0    1045
# Name: count, dtype: int64
# Test graph for hour 1876 saved to 3ed_tes_h_graphs/test_graph_hour_1876.gpickle
# Hour 1877:
# Label
# 0    18
# Name: count, dtype: int64
# Test graph for hour 1877 saved to 3ed_tes_h_graphs/test_graph_hour_1877.gpickle
# Hour 1878:
# Label
# 0    753
# Name: count, dtype: int64
# Test graph for hour 1878 saved to 3ed_tes_h_graphs/test_graph_hour_1878.gpickle
# Hour 1879:
# Label
# 0    60
# Name: count, dtype: int64
# Test graph for hour 1879 saved to 3ed_tes_h_graphs/test_graph_hour_1879.gpickle
# Hour 1880:
# Label
# 0    18
# Name: count, dtype: int64
# Test graph for hour 1880 saved to 3ed_tes_h_graphs/test_graph_hour_1880.gpickle
# Hour 1881:
# Label
# 0    9
# Name: count, dtype: int64
# Test graph for hour 1881 saved to 3ed_tes_h_graphs/test_graph_hour_1881.gpickle
# Hour 1882:
# Label
# 0    8
# Name: count, dtype: int64
# Test graph for hour 1882 saved to 3ed_tes_h_graphs/test_graph_hour_1882.gpickle
# Hour 1883:
# Label
# 0    15
# Name: count, dtype: int64
# Test graph for hour 1883 saved to 3ed_tes_h_graphs/test_graph_hour_1883.gpickle
# Hour 1884:
# Label
# 0    6
# Name: count, dtype: int64
# Test graph for hour 1884 saved to 3ed_tes_h_graphs/test_graph_hour_1884.gpickle
# Hour 1885:
# Label
# 0    12
# Name: count, dtype: int64
# Test graph for hour 1885 saved to 3ed_tes_h_graphs/test_graph_hour_1885.gpickle
# Hour 1886:
# Label
# 0    14
# Name: count, dtype: int64
# Test graph for hour 1886 saved to 3ed_tes_h_graphs/test_graph_hour_1886.gpickle
# Hour 1887:
# Label
# 0    12
# Name: count, dtype: int64
# Test graph for hour 1887 saved to 3ed_tes_h_graphs/test_graph_hour_1887.gpickle
# Hour 1888:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1888 saved to 3ed_tes_h_graphs/test_graph_hour_1888.gpickle
# Hour 1889:
# Label
# 0    783
# Name: count, dtype: int64
# Test graph for hour 1889 saved to 3ed_tes_h_graphs/test_graph_hour_1889.gpickle
# Hour 1890:
# Label
# 0    97
# Name: count, dtype: int64
# Test graph for hour 1890 saved to 3ed_tes_h_graphs/test_graph_hour_1890.gpickle
# Hour 1891:
# Label
# 0    145
# Name: count, dtype: int64
# Test graph for hour 1891 saved to 3ed_tes_h_graphs/test_graph_hour_1891.gpickle
# Hour 1892:
# Label
# 0    53
# Name: count, dtype: int64
# Test graph for hour 1892 saved to 3ed_tes_h_graphs/test_graph_hour_1892.gpickle
# Hour 1893:
# Label
# 0    811
# Name: count, dtype: int64
# Test graph for hour 1893 saved to 3ed_tes_h_graphs/test_graph_hour_1893.gpickle
# Hour 1894:
# Label
# 0    29
# Name: count, dtype: int64
# Test graph for hour 1894 saved to 3ed_tes_h_graphs/test_graph_hour_1894.gpickle
# Hour 1895:
# Label
# 0    731
# Name: count, dtype: int64
# Test graph for hour 1895 saved to 3ed_tes_h_graphs/test_graph_hour_1895.gpickle
# Hour 1904:
# Label
# 0    23
# Name: count, dtype: int64
# Test graph for hour 1904 saved to 3ed_tes_h_graphs/test_graph_hour_1904.gpickle
# Hour 1905:
# Label
# 0    46
# Name: count, dtype: int64
# Test graph for hour 1905 saved to 3ed_tes_h_graphs/test_graph_hour_1905.gpickle
# Hour 1906:
# Label
# 0    39
# Name: count, dtype: int64
# Test graph for hour 1906 saved to 3ed_tes_h_graphs/test_graph_hour_1906.gpickle
# Hour 1907:
# Label
# 0    36
# Name: count, dtype: int64
# Test graph for hour 1907 saved to 3ed_tes_h_graphs/test_graph_hour_1907.gpickle
# Hour 1908:
# Label
# 0    50
# Name: count, dtype: int64
# Test graph for hour 1908 saved to 3ed_tes_h_graphs/test_graph_hour_1908.gpickle
# Hour 1909:
# Label
# 0    58
# Name: count, dtype: int64
# Test graph for hour 1909 saved to 3ed_tes_h_graphs/test_graph_hour_1909.gpickle
# Hour 1910:
# Label
# 0    61
# Name: count, dtype: int64
# Test graph for hour 1910 saved to 3ed_tes_h_graphs/test_graph_hour_1910.gpickle
# Hour 1911:
# Label
# 0    41
# Name: count, dtype: int64
# Test graph for hour 1911 saved to 3ed_tes_h_graphs/test_graph_hour_1911.gpickle
# Hour 1912:
# Label
# 0    46
# Name: count, dtype: int64
# Test graph for hour 1912 saved to 3ed_tes_h_graphs/test_graph_hour_1912.gpickle
# Hour 1916:
# Label
# 0    16
# Name: count, dtype: int64
# Test graph for hour 1916 saved to 3ed_tes_h_graphs/test_graph_hour_1916.gpickle
# Hour 1917:
# Label
# 0    12
# Name: count, dtype: int64
# Test graph for hour 1917 saved to 3ed_tes_h_graphs/test_graph_hour_1917.gpickle
# Hour 1918:
# Label
# 0    25
# Name: count, dtype: int64
# Test graph for hour 1918 saved to 3ed_tes_h_graphs/test_graph_hour_1918.gpickle
# Hour 1919:
# Label
# 0    18
# Name: count, dtype: int64
# Test graph for hour 1919 saved to 3ed_tes_h_graphs/test_graph_hour_1919.gpickle
# Hour 1920:
# Label
# 0    8
# Name: count, dtype: int64
# Test graph for hour 1920 saved to 3ed_tes_h_graphs/test_graph_hour_1920.gpickle
# Hour 1924:
# Label
# 0    7
# Name: count, dtype: int64
# Test graph for hour 1924 saved to 3ed_tes_h_graphs/test_graph_hour_1924.gpickle
# Hour 1925:
# Label
# 0    104
# Name: count, dtype: int64
# Test graph for hour 1925 saved to 3ed_tes_h_graphs/test_graph_hour_1925.gpickle
# Hour 1926:
# Label
# 0    153
# Name: count, dtype: int64
# Test graph for hour 1926 saved to 3ed_tes_h_graphs/test_graph_hour_1926.gpickle
# Hour 1927:
# Label
# 0    101
# Name: count, dtype: int64
# Test graph for hour 1927 saved to 3ed_tes_h_graphs/test_graph_hour_1927.gpickle
# Hour 1928:
# Label
# 0    105
# Name: count, dtype: int64
# Test graph for hour 1928 saved to 3ed_tes_h_graphs/test_graph_hour_1928.gpickle
# Hour 1929:
# Label
# 0    226
# Name: count, dtype: int64
# Test graph for hour 1929 saved to 3ed_tes_h_graphs/test_graph_hour_1929.gpickle
# Hour 1930:
# Label
# 0    222
# Name: count, dtype: int64
# Test graph for hour 1930 saved to 3ed_tes_h_graphs/test_graph_hour_1930.gpickle
# Hour 1931:
# Label
# 0    245
# Name: count, dtype: int64
# Test graph for hour 1931 saved to 3ed_tes_h_graphs/test_graph_hour_1931.gpickle
# Hour 1932:
# Label
# 0    277
# Name: count, dtype: int64
# Test graph for hour 1932 saved to 3ed_tes_h_graphs/test_graph_hour_1932.gpickle
# Hour 1933:
# Label
# 0    281
# Name: count, dtype: int64
# Test graph for hour 1933 saved to 3ed_tes_h_graphs/test_graph_hour_1933.gpickle
# Hour 1934:
# Label
# 0    225
# Name: count, dtype: int64
# Test graph for hour 1934 saved to 3ed_tes_h_graphs/test_graph_hour_1934.gpickle
# Hour 1935:
# Label
# 0    287
# Name: count, dtype: int64
# Test graph for hour 1935 saved to 3ed_tes_h_graphs/test_graph_hour_1935.gpickle
# Hour 1936:
# Label
# 0    168
# Name: count, dtype: int64
# Test graph for hour 1936 saved to 3ed_tes_h_graphs/test_graph_hour_1936.gpickle
# Hour 1937:
# Label
# 0    102
# Name: count, dtype: int64
# Test graph for hour 1937 saved to 3ed_tes_h_graphs/test_graph_hour_1937.gpickle
# Hour 1938:
# Label
# 0    146
# Name: count, dtype: int64
# Test graph for hour 1938 saved to 3ed_tes_h_graphs/test_graph_hour_1938.gpickle
# Hour 1939:
# Label
# 0    199
# Name: count, dtype: int64
# Test graph for hour 1939 saved to 3ed_tes_h_graphs/test_graph_hour_1939.gpickle
# Hour 1940:
# Label
# 0    115
# Name: count, dtype: int64
# Test graph for hour 1940 saved to 3ed_tes_h_graphs/test_graph_hour_1940.gpickle
# Hour 1941:
# Label
# 0    18
# Name: count, dtype: int64
# Test graph for hour 1941 saved to 3ed_tes_h_graphs/test_graph_hour_1941.gpickle
# Hour 1947:
# Label
# 0    3
# Name: count, dtype: int64
# Test graph for hour 1947 saved to 3ed_tes_h_graphs/test_graph_hour_1947.gpickle
# Hour 1948:
# Label
# 0    26
# Name: count, dtype: int64
# Test graph for hour 1948 saved to 3ed_tes_h_graphs/test_graph_hour_1948.gpickle
# Hour 1949:
# Label
# 0    20
# Name: count, dtype: int64
# Test graph for hour 1949 saved to 3ed_tes_h_graphs/test_graph_hour_1949.gpickle
# Hour 1950:
# Label
# 0    20
# Name: count, dtype: int64
# Test graph for hour 1950 saved to 3ed_tes_h_graphs/test_graph_hour_1950.gpickle
# Hour 1951:
# Label
# 0    39
# Name: count, dtype: int64
# Test graph for hour 1951 saved to 3ed_tes_h_graphs/test_graph_hour_1951.gpickle
# Hour 1952:
# Label
# 0    49
# Name: count, dtype: int64
# Test graph for hour 1952 saved to 3ed_tes_h_graphs/test_graph_hour_1952.gpickle
# Hour 1953:
# Label
# 0    45
# Name: count, dtype: int64
# Test graph for hour 1953 saved to 3ed_tes_h_graphs/test_graph_hour_1953.gpickle
# Hour 1954:
# Label
# 0    53
# Name: count, dtype: int64
# Test graph for hour 1954 saved to 3ed_tes_h_graphs/test_graph_hour_1954.gpickle
# Hour 1955:
# Label
# 0    51
# Name: count, dtype: int64
# Test graph for hour 1955 saved to 3ed_tes_h_graphs/test_graph_hour_1955.gpickle
# Hour 1956:
# Label
# 0    62
# Name: count, dtype: int64
# Test graph for hour 1956 saved to 3ed_tes_h_graphs/test_graph_hour_1956.gpickle
# Hour 1957:
# Label
# 0    54
# Name: count, dtype: int64
# Test graph for hour 1957 saved to 3ed_tes_h_graphs/test_graph_hour_1957.gpickle
# Hour 1958:
# Label
# 0    53
# Name: count, dtype: int64
# Test graph for hour 1958 saved to 3ed_tes_h_graphs/test_graph_hour_1958.gpickle
# Hour 1959:
# Label
# 0    76
# Name: count, dtype: int64
# Test graph for hour 1959 saved to 3ed_tes_h_graphs/test_graph_hour_1959.gpickle
# Hour 1960:
# Label
# 0    88
# Name: count, dtype: int64
# Test graph for hour 1960 saved to 3ed_tes_h_graphs/test_graph_hour_1960.gpickle
# Hour 1961:
# Label
# 0    51
# Name: count, dtype: int64
# Test graph for hour 1961 saved to 3ed_tes_h_graphs/test_graph_hour_1961.gpickle
# Hour 1962:
# Label
# 1    1003
# 0     154
# Name: count, dtype: int64
# Test graph for hour 1962 saved to 3ed_tes_h_graphs/test_graph_hour_1962.gpickle
# Hour 1963:
# Label
# 1    14804
# 0     6315
# Name: count, dtype: int64
# Test graph for hour 1963 saved to 3ed_tes_h_graphs/test_graph_hour_1963.gpickle
# Hour 1964:
# Label
# 1    14288
# 0    11617
# Name: count, dtype: int64
# Test graph for hour 1964 saved to 3ed_tes_h_graphs/test_graph_hour_1964.gpickle
# Hour 1965:
# Label
# 1    14050
# 0     8537
# Name: count, dtype: int64
# Test graph for hour 1965 saved to 3ed_tes_h_graphs/test_graph_hour_1965.gpickle
# Hour 1966:
# Label
# 1    14324
# 0     9107
# Name: count, dtype: int64
# Test graph for hour 1966 saved to 3ed_tes_h_graphs/test_graph_hour_1966.gpickle
# Hour 1967:
# Label
# 1    15443
# 0     8637
# Name: count, dtype: int64
# Test graph for hour 1967 saved to 3ed_tes_h_graphs/test_graph_hour_1967.gpickle
# Hour 1968:
# Label
# 1    14870
# 0     9287
# Name: count, dtype: int64
# Test graph for hour 1968 saved to 3ed_tes_h_graphs/test_graph_hour_1968.gpickle
# Hour 1969:
# Label
# 1    14837
# 0     9098
# Name: count, dtype: int64
# Test graph for hour 1969 saved to 3ed_tes_h_graphs/test_graph_hour_1969.gpickle
# Hour 1970:
# Label
# 1    8459
# 0    6720
# Name: count, dtype: int64
# Test graph for hour 1970 saved to 3ed_tes_h_graphs/test_graph_hour_1970.gpickle
# Hour 1985:
# Label
# 0    73
# Name: count, dtype: int64
# Test graph for hour 1985 saved to 3ed_tes_h_graphs/test_graph_hour_1985.gpickle
# Hour 1986:
# Label
# 0    438
# 1     70
# Name: count, dtype: int64
# Test graph for hour 1986 saved to 3ed_tes_h_graphs/test_graph_hour_1986.gpickle
# Hour 1987:
# Label
# 0    3069
# 1     131
# Name: count, dtype: int64
# Test graph for hour 1987 saved to 3ed_tes_h_graphs/test_graph_hour_1987.gpickle
# Hour 1988:
# Label
# 0    155
# Name: count, dtype: int64
# Test graph for hour 1988 saved to 3ed_tes_h_graphs/test_graph_hour_1988.gpickle
# Hour 1989:
# Label
# 0    445
# 1     18
# Name: count, dtype: int64
# Test graph for hour 1989 saved to 3ed_tes_h_graphs/test_graph_hour_1989.gpickle
# Hour 1990:
# Label
# 0    228
# 1     27
# Name: count, dtype: int64
# Test graph for hour 1990 saved to 3ed_tes_h_graphs/test_graph_hour_1990.gpickle
# Hour 1991:
# Label
# 0    217
# 1     40
# Name: count, dtype: int64
# Test graph for hour 1991 saved to 3ed_tes_h_graphs/test_graph_hour_1991.gpickle
# Hour 1992:
# Label
# 0    199
# 1     38
# Name: count, dtype: int64
# Test graph for hour 1992 saved to 3ed_tes_h_graphs/test_graph_hour_1992.gpickle
# Hour 1993:
# Label
# 0    98
# 1    22
# Name: count, dtype: int64
# Test graph for hour 1993 saved to 3ed_tes_h_graphs/test_graph_hour_1993.gpickle
# Hour 1994:
# Label
# 0    68
# 1    38
# Name: count, dtype: int64
# Test graph for hour 1994 saved to 3ed_tes_h_graphs/test_graph_hour_1994.gpickle
# Hour 1995:
# Label
# 0    84
# 1    30
# Name: count, dtype: int64
# Test graph for hour 1995 saved to 3ed_tes_h_graphs/test_graph_hour_1995.gpickle
# Hour 1996:
# Label
# 0    68
# 1    30
# Name: count, dtype: int64
# Test graph for hour 1996 saved to 3ed_tes_h_graphs/test_graph_hour_1996.gpickle
# Hour 1997:
# Label
# 0    69
# 1    32
# Name: count, dtype: int64
# Test graph for hour 1997 saved to 3ed_tes_h_graphs/test_graph_hour_1997.gpickle
# Hour 1998:
# Label
# 0    83
# 1    31
# Name: count, dtype: int64
# Test graph for hour 1998 saved to 3ed_tes_h_graphs/test_graph_hour_1998.gpickle
# Hour 1999:
# Label
# 0    70
# 1    24
# Name: count, dtype: int64
# Test graph for hour 1999 saved to 3ed_tes_h_graphs/test_graph_hour_1999.gpickle
# Hour 2000:
# Label
# 0    74
# 1    25
# Name: count, dtype: int64
# Test graph for hour 2000 saved to 3ed_tes_h_graphs/test_graph_hour_2000.gpickle
# Hour 2001:
# Label
# 0    98
# 1    39
# Name: count, dtype: int64
# Test graph for hour 2001 saved to 3ed_tes_h_graphs/test_graph_hour_2001.gpickle
# Hour 2002:
# Label
# 0    72
# 1    52
# Name: count, dtype: int64
# Test graph for hour 2002 saved to 3ed_tes_h_graphs/test_graph_hour_2002.gpickle
# Hour 2003:
# Label
# 0    51
# 1    51
# Name: count, dtype: int64
# Test graph for hour 2003 saved to 3ed_tes_h_graphs/test_graph_hour_2003.gpickle
# Hour 2004:
# Label
# 0    74
# 1    51
# Name: count, dtype: int64
# Test graph for hour 2004 saved to 3ed_tes_h_graphs/test_graph_hour_2004.gpickle
# Hour 2005:
# Label
# 0    65
# 1    55
# Name: count, dtype: int64
# Test graph for hour 2005 saved to 3ed_tes_h_graphs/test_graph_hour_2005.gpickle
# Hour 2006:
# Label
# 0    59
# 1    56
# Name: count, dtype: int64
# Test graph for hour 2006 saved to 3ed_tes_h_graphs/test_graph_hour_2006.gpickle
# Hour 2007:
# Label
# 0    65
# 1    56
# Name: count, dtype: int64
# Test graph for hour 2007 saved to 3ed_tes_h_graphs/test_graph_hour_2007.gpickle
# Hour 2008:
# Label
# 0    60
# 1    51
# Name: count, dtype: int64
# Test graph for hour 2008 saved to 3ed_tes_h_graphs/test_graph_hour_2008.gpickle
# Hour 2009:
# Label
# 0    69
# 1    57
# Name: count, dtype: int64
# Test graph for hour 2009 saved to 3ed_tes_h_graphs/test_graph_hour_2009.gpickle
# Hour 2010:
# Label
# 0    64
# 1    58
# Name: count, dtype: int64
# Test graph for hour 2010 saved to 3ed_tes_h_graphs/test_graph_hour_2010.gpickle
# Hour 2011:
# Label
# 0    68
# 1    64
# Name: count, dtype: int64
# Test graph for hour 2011 saved to 3ed_tes_h_graphs/test_graph_hour_2011.gpickle
# Hour 2012:
# Label
# 0    76
# 1    61
# Name: count, dtype: int64
# Test graph for hour 2012 saved to 3ed_tes_h_graphs/test_graph_hour_2012.gpickle
# Hour 2013:
# Label
# 0    55
# 1    47
# Name: count, dtype: int64
# Test graph for hour 2013 saved to 3ed_tes_h_graphs/test_graph_hour_2013.gpickle
# Hour 2014:
# Label
# 0    76
# 1    58
# Name: count, dtype: int64
# Test graph for hour 2014 saved to 3ed_tes_h_graphs/test_graph_hour_2014.gpickle
# Hour 2015:
# Label
# 0    79
# 1    26
# Name: count, dtype: int64
# Test graph for hour 2015 saved to 3ed_tes_h_graphs/test_graph_hour_2015.gpickle
# Hour 2018:
# Label
# 0    3301
# 1      23
# Name: count, dtype: int64
# Test graph for hour 2018 saved to 3ed_tes_h_graphs/test_graph_hour_2018.gpickle
# Hour 2019:
# Label
# 0    101
# 1     18
# Name: count, dtype: int64
# Test graph for hour 2019 saved to 3ed_tes_h_graphs/test_graph_hour_2019.gpickle
# Hour 2020:
# Label
# 0    11603
# 1        4
# Name: count, dtype: int64
# Test graph for hour 2020 saved to 3ed_tes_h_graphs/test_graph_hour_2020.gpickle

# %%
#########Riplika of previous code:
import pandas as pd
import networkx as nx
import os

def add_node_features(G):
    """
    Adds additional features to nodes in the graph, including:
    - Node degree
    - Community ID
    - Temporal activity (average edge count per node)
    - Node centrality (betweenness centrality)

    Parameters:
        G (nx.MultiDiGraph): The input graph.

    Returns:
        nx.MultiDiGraph: The graph with added node features.
    """
    # Add degree
    for node in G.nodes:
        G.nodes[node]['degree'] = G.degree[node]

    # Add community detection (Label Propagation)
    undirected_graph = nx.Graph(G)  # Convert to undirected for community detection
    communities = nx.community.label_propagation_communities(undirected_graph)
    community_mapping = {node: community_id for community_id, community in enumerate(communities) for node in community}
    for node in G.nodes:
        G.nodes[node]['community'] = community_mapping.get(node, -1)

    # Add centrality (Betweenness Centrality)
    centrality = nx.betweenness_centrality(G)
    for node, value in centrality.items():
        G.nodes[node]['centrality'] = value

    return G

def create_test_graphs_edge_labels(df, output_dir):
    """
    Split the DataFrame into hourly slices and create graphs for each slice.
    Each edge gets a valid label (e.g., 0 or 1) read from the DataFrame.
    
    Parameters:
        df (pd.DataFrame): The input DataFrame with temporal data.
        output_dir (str): Directory to save the graphs.
    """
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Group the DataFrame into hourly slices using the datetime index.
    time_slices = [g for _, g in df.groupby(pd.Grouper(freq='h'))]
    
    for slice_index, slice_df in enumerate(time_slices):
        if slice_df.empty:
            continue

        # Print value counts of the 'Label' column in this time-slice.
        print(f"Hour {slice_index}:")
        print(slice_df['Label'].value_counts())
        
        # Create a MultiDiGraph for this time-slice.
        G = nx.MultiDiGraph()

        for _, row in slice_df.iterrows():
            src_ip = row['Src IP']
            dst_ip = row['Dst IP']
            
            # Convert the label to an int (if missing or invalid, you can decide a fallback; here we assume it is valid)
            try:
                label = int(row['Label'])
            except Exception as e:
                print(f"Skipping row due to invalid label: {row['Label']}; error: {e}")
                continue

            if pd.isna(src_ip) or pd.isna(dst_ip):
                continue

            # Add nodes if not already present.
            if not G.has_node(src_ip):
                G.add_node(src_ip)
            if not G.has_node(dst_ip):
                G.add_node(dst_ip)

            # Add edges conditionally based on the active config
            # 1. Network Edge
            if 'network' in active_edges:
                net_attrs = {feat: row[feat] for feat in network_features if feat in row}
                G.add_edge(src_ip, dst_ip, key='network', label=label, interaction='network_communication', **net_attrs)

            # 2. Context Edge
            if 'context' in active_edges:
                ctx_attrs = {feat: row[feat] for feat in context_features if feat in row}
                G.add_edge(src_ip, dst_ip, key='context', label=label, interaction='context', **ctx_attrs)

            # 3. Knowledge Edge
            if 'knowledge' in active_edges:
                knw_attrs = {feat: row[feat] for feat in knowledge_features if feat in row}
                G.add_edge(src_ip, dst_ip, key='knowledge', label=label, interaction='knowledge', **knw_attrs)

        # Add node features
        G = add_node_features(G)

        # Save the graph as a .gpickle file.
        graph_path = os.path.join(output_dir, f"test_graph_hour_{slice_index}.gpickle")
        nx.write_gpickle(G, graph_path)
        print(f"Test graph for hour {slice_index} saved to {graph_path}")

# Usage Example for graph creation
if __name__ == "__main__":
    # Read CSV and prepare DataFrame.
    df_test = pd.read_csv('filtered_test_3edge.csv')
    df_test['Timestamp'] = pd.to_datetime(df_test['Timestamp'])
    # Set Timestamp as index and sort (required for grouping by hour)
    df_test = df_test.set_index('Timestamp').sort_index()

    output_test_dir = "3ed_tes_h_graphs"
    create_test_graphs_edge_labels(df_test, output_test_dir)
# Out:
# Hour 0:
# Label
# 0    3
# Name: count, dtype: int64
# Test graph for hour 0 saved to 3ed_tes_h_graphs/test_graph_hour_0.gpickle
# Hour 1:
# Label
# 0    4
# Name: count, dtype: int64
# Test graph for hour 1 saved to 3ed_tes_h_graphs/test_graph_hour_1.gpickle
# Hour 2:
# Label
# 0    5
# Name: count, dtype: int64
# Test graph for hour 2 saved to 3ed_tes_h_graphs/test_graph_hour_2.gpickle
# Hour 3:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 3 saved to 3ed_tes_h_graphs/test_graph_hour_3.gpickle
# Hour 652:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 652 saved to 3ed_tes_h_graphs/test_graph_hour_652.gpickle
# Hour 653:
# Label
# 0    4
# Name: count, dtype: int64
# Test graph for hour 653 saved to 3ed_tes_h_graphs/test_graph_hour_653.gpickle
# Hour 654:
# Label
# 0    9
# Name: count, dtype: int64
# Test graph for hour 654 saved to 3ed_tes_h_graphs/test_graph_hour_654.gpickle
# Hour 655:
# Label
# 0    2
# Name: count, dtype: int64
# Test graph for hour 655 saved to 3ed_tes_h_graphs/test_graph_hour_655.gpickle
# Hour 656:
# Label
# 0    3
# Name: count, dtype: int64
# Test graph for hour 656 saved to 3ed_tes_h_graphs/test_graph_hour_656.gpickle
# Hour 657:
# Label
# 0    2
# Name: count, dtype: int64
# Test graph for hour 657 saved to 3ed_tes_h_graphs/test_graph_hour_657.gpickle
# Hour 658:
# Label
# 0    7
# Name: count, dtype: int64
# Test graph for hour 658 saved to 3ed_tes_h_graphs/test_graph_hour_658.gpickle
# Hour 670:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 670 saved to 3ed_tes_h_graphs/test_graph_hour_670.gpickle
# Hour 671:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 671 saved to 3ed_tes_h_graphs/test_graph_hour_671.gpickle
# Hour 672:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 672 saved to 3ed_tes_h_graphs/test_graph_hour_672.gpickle
# Hour 673:
# Label
# 0    3
# Name: count, dtype: int64
# Test graph for hour 673 saved to 3ed_tes_h_graphs/test_graph_hour_673.gpickle
# Hour 674:
# Label
# 0    3
# Name: count, dtype: int64
# Test graph for hour 674 saved to 3ed_tes_h_graphs/test_graph_hour_674.gpickle
# Hour 675:
# Label
# 0    2
# Name: count, dtype: int64
# Test graph for hour 675 saved to 3ed_tes_h_graphs/test_graph_hour_675.gpickle
# Hour 1397:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1397 saved to 3ed_tes_h_graphs/test_graph_hour_1397.gpickle
# Hour 1398:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1398 saved to 3ed_tes_h_graphs/test_graph_hour_1398.gpickle
# Hour 1399:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1399 saved to 3ed_tes_h_graphs/test_graph_hour_1399.gpickle
# Hour 1400:
# Label
# 0    2
# Name: count, dtype: int64
# Test graph for hour 1400 saved to 3ed_tes_h_graphs/test_graph_hour_1400.gpickle
# Hour 1401:
# Label
# 0    2
# Name: count, dtype: int64
# Test graph for hour 1401 saved to 3ed_tes_h_graphs/test_graph_hour_1401.gpickle
# Hour 1402:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1402 saved to 3ed_tes_h_graphs/test_graph_hour_1402.gpickle
# Hour 1404:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1404 saved to 3ed_tes_h_graphs/test_graph_hour_1404.gpickle
# Hour 1405:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1405 saved to 3ed_tes_h_graphs/test_graph_hour_1405.gpickle
# Hour 1406:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1406 saved to 3ed_tes_h_graphs/test_graph_hour_1406.gpickle
# Hour 1407:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1407 saved to 3ed_tes_h_graphs/test_graph_hour_1407.gpickle
# Hour 1410:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1410 saved to 3ed_tes_h_graphs/test_graph_hour_1410.gpickle
# Hour 1411:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1411 saved to 3ed_tes_h_graphs/test_graph_hour_1411.gpickle
# Hour 1412:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1412 saved to 3ed_tes_h_graphs/test_graph_hour_1412.gpickle
# Hour 1874:
# Label
# 0    9
# Name: count, dtype: int64
# Test graph for hour 1874 saved to 3ed_tes_h_graphs/test_graph_hour_1874.gpickle
# Hour 1875:
# Label
# 0    818
# Name: count, dtype: int64
# Test graph for hour 1875 saved to 3ed_tes_h_graphs/test_graph_hour_1875.gpickle
# Hour 1876:
# Label
# 0    1045
# Name: count, dtype: int64
# Test graph for hour 1876 saved to 3ed_tes_h_graphs/test_graph_hour_1876.gpickle
# Hour 1877:
# Label
# 0    18
# Name: count, dtype: int64
# Test graph for hour 1877 saved to 3ed_tes_h_graphs/test_graph_hour_1877.gpickle
# Hour 1878:
# Label
# 0    753
# Name: count, dtype: int64
# Test graph for hour 1878 saved to 3ed_tes_h_graphs/test_graph_hour_1878.gpickle
# Hour 1879:
# Label
# 0    60
# Name: count, dtype: int64
# Test graph for hour 1879 saved to 3ed_tes_h_graphs/test_graph_hour_1879.gpickle
# Hour 1880:
# Label
# 0    18
# Name: count, dtype: int64
# Test graph for hour 1880 saved to 3ed_tes_h_graphs/test_graph_hour_1880.gpickle
# Hour 1881:
# Label
# 0    9
# Name: count, dtype: int64
# Test graph for hour 1881 saved to 3ed_tes_h_graphs/test_graph_hour_1881.gpickle
# Hour 1882:
# Label
# 0    8
# Name: count, dtype: int64
# Test graph for hour 1882 saved to 3ed_tes_h_graphs/test_graph_hour_1882.gpickle
# Hour 1883:
# Label
# 0    15
# Name: count, dtype: int64
# Test graph for hour 1883 saved to 3ed_tes_h_graphs/test_graph_hour_1883.gpickle
# Hour 1884:
# Label
# 0    6
# Name: count, dtype: int64
# Test graph for hour 1884 saved to 3ed_tes_h_graphs/test_graph_hour_1884.gpickle
# Hour 1885:
# Label
# 0    12
# Name: count, dtype: int64
# Test graph for hour 1885 saved to 3ed_tes_h_graphs/test_graph_hour_1885.gpickle
# Hour 1886:
# Label
# 0    14
# Name: count, dtype: int64
# Test graph for hour 1886 saved to 3ed_tes_h_graphs/test_graph_hour_1886.gpickle
# Hour 1887:
# Label
# 0    12
# Name: count, dtype: int64
# Test graph for hour 1887 saved to 3ed_tes_h_graphs/test_graph_hour_1887.gpickle
# Hour 1888:
# Label
# 0    1
# Name: count, dtype: int64
# Test graph for hour 1888 saved to 3ed_tes_h_graphs/test_graph_hour_1888.gpickle
# Hour 1889:
# Label
# 0    783
# Name: count, dtype: int64
# Test graph for hour 1889 saved to 3ed_tes_h_graphs/test_graph_hour_1889.gpickle
# Hour 1890:
# Label
# 0    97
# Name: count, dtype: int64
# Test graph for hour 1890 saved to 3ed_tes_h_graphs/test_graph_hour_1890.gpickle
# Hour 1891:
# Label
# 0    145
# Name: count, dtype: int64
# Test graph for hour 1891 saved to 3ed_tes_h_graphs/test_graph_hour_1891.gpickle
# Hour 1892:
# Label
# 0    53
# Name: count, dtype: int64
# Test graph for hour 1892 saved to 3ed_tes_h_graphs/test_graph_hour_1892.gpickle
# Hour 1893:
# Label
# 0    811
# Name: count, dtype: int64
# Test graph for hour 1893 saved to 3ed_tes_h_graphs/test_graph_hour_1893.gpickle
# Hour 1894:
# Label
# 0    29
# Name: count, dtype: int64
# Test graph for hour 1894 saved to 3ed_tes_h_graphs/test_graph_hour_1894.gpickle
# Hour 1895:
# Label
# 0    731
# Name: count, dtype: int64
# Test graph for hour 1895 saved to 3ed_tes_h_graphs/test_graph_hour_1895.gpickle
# Hour 1904:
# Label
# 0    23
# Name: count, dtype: int64
# Test graph for hour 1904 saved to 3ed_tes_h_graphs/test_graph_hour_1904.gpickle
# Hour 1905:
# Label
# 0    46
# Name: count, dtype: int64
# Test graph for hour 1905 saved to 3ed_tes_h_graphs/test_graph_hour_1905.gpickle
# Hour 1906:
# Label
# 0    39
# Name: count, dtype: int64
# Test graph for hour 1906 saved to 3ed_tes_h_graphs/test_graph_hour_1906.gpickle
# Hour 1907:
# Label
# 0    36
# Name: count, dtype: int64
# Test graph for hour 1907 saved to 3ed_tes_h_graphs/test_graph_hour_1907.gpickle
# Hour 1908:
# Label
# 0    50
# Name: count, dtype: int64
# Test graph for hour 1908 saved to 3ed_tes_h_graphs/test_graph_hour_1908.gpickle
# Hour 1909:
# Label
# 0    58
# Name: count, dtype: int64
# Test graph for hour 1909 saved to 3ed_tes_h_graphs/test_graph_hour_1909.gpickle
# Hour 1910:
# Label
# 0    61
# Name: count, dtype: int64
# Test graph for hour 1910 saved to 3ed_tes_h_graphs/test_graph_hour_1910.gpickle
# Hour 1911:
# Label
# 0    41
# Name: count, dtype: int64
# Test graph for hour 1911 saved to 3ed_tes_h_graphs/test_graph_hour_1911.gpickle
# Hour 1912:
# Label
# 0    46
# Name: count, dtype: int64
# Test graph for hour 1912 saved to 3ed_tes_h_graphs/test_graph_hour_1912.gpickle
# Hour 1916:
# Label
# 0    16
# Name: count, dtype: int64
# Test graph for hour 1916 saved to 3ed_tes_h_graphs/test_graph_hour_1916.gpickle
# Hour 1917:
# Label
# 0    12
# Name: count, dtype: int64
# Test graph for hour 1917 saved to 3ed_tes_h_graphs/test_graph_hour_1917.gpickle
# Hour 1918:
# Label
# 0    25
# Name: count, dtype: int64
# Test graph for hour 1918 saved to 3ed_tes_h_graphs/test_graph_hour_1918.gpickle
# Hour 1919:
# Label
# 0    18
# Name: count, dtype: int64
# Test graph for hour 1919 saved to 3ed_tes_h_graphs/test_graph_hour_1919.gpickle
# Hour 1920:
# Label
# 0    8
# Name: count, dtype: int64
# Test graph for hour 1920 saved to 3ed_tes_h_graphs/test_graph_hour_1920.gpickle
# Hour 1924:
# Label
# 0    7
# Name: count, dtype: int64
# Test graph for hour 1924 saved to 3ed_tes_h_graphs/test_graph_hour_1924.gpickle
# Hour 1925:
# Label
# 0    104
# Name: count, dtype: int64
# Test graph for hour 1925 saved to 3ed_tes_h_graphs/test_graph_hour_1925.gpickle
# Hour 1926:
# Label
# 0    153
# Name: count, dtype: int64
# Test graph for hour 1926 saved to 3ed_tes_h_graphs/test_graph_hour_1926.gpickle
# Hour 1927:
# Label
# 0    101
# Name: count, dtype: int64
# Test graph for hour 1927 saved to 3ed_tes_h_graphs/test_graph_hour_1927.gpickle
# Hour 1928:
# Label
# 0    105
# Name: count, dtype: int64
# Test graph for hour 1928 saved to 3ed_tes_h_graphs/test_graph_hour_1928.gpickle
# Hour 1929:
# Label
# 0    226
# Name: count, dtype: int64
# Test graph for hour 1929 saved to 3ed_tes_h_graphs/test_graph_hour_1929.gpickle
# Hour 1930:
# Label
# 0    222
# Name: count, dtype: int64
# Test graph for hour 1930 saved to 3ed_tes_h_graphs/test_graph_hour_1930.gpickle
# Hour 1931:
# Label
# 0    245
# Name: count, dtype: int64
# Test graph for hour 1931 saved to 3ed_tes_h_graphs/test_graph_hour_1931.gpickle
# Hour 1932:
# Label
# 0    277
# Name: count, dtype: int64
# Test graph for hour 1932 saved to 3ed_tes_h_graphs/test_graph_hour_1932.gpickle
# Hour 1933:
# Label
# 0    281
# Name: count, dtype: int64
# Test graph for hour 1933 saved to 3ed_tes_h_graphs/test_graph_hour_1933.gpickle
# Hour 1934:
# Label
# 0    225
# Name: count, dtype: int64
# Test graph for hour 1934 saved to 3ed_tes_h_graphs/test_graph_hour_1934.gpickle
# Hour 1935:
# Label
# 0    287
# Name: count, dtype: int64
# Test graph for hour 1935 saved to 3ed_tes_h_graphs/test_graph_hour_1935.gpickle
# Hour 1936:
# Label
# 0    168
# Name: count, dtype: int64
# Test graph for hour 1936 saved to 3ed_tes_h_graphs/test_graph_hour_1936.gpickle
# Hour 1937:
# Label
# 0    102
# Name: count, dtype: int64
# Test graph for hour 1937 saved to 3ed_tes_h_graphs/test_graph_hour_1937.gpickle
# Hour 1938:
# Label
# 0    146
# Name: count, dtype: int64
# Test graph for hour 1938 saved to 3ed_tes_h_graphs/test_graph_hour_1938.gpickle
# Hour 1939:
# Label
# 0    199
# Name: count, dtype: int64
# Test graph for hour 1939 saved to 3ed_tes_h_graphs/test_graph_hour_1939.gpickle
# Hour 1940:
# Label
# 0    115
# Name: count, dtype: int64
# Test graph for hour 1940 saved to 3ed_tes_h_graphs/test_graph_hour_1940.gpickle
# Hour 1941:
# Label
# 0    18
# Name: count, dtype: int64
# Test graph for hour 1941 saved to 3ed_tes_h_graphs/test_graph_hour_1941.gpickle
# Hour 1947:
# Label
# 0    3
# Name: count, dtype: int64
# Test graph for hour 1947 saved to 3ed_tes_h_graphs/test_graph_hour_1947.gpickle
# Hour 1948:
# Label
# 0    26
# Name: count, dtype: int64
# Test graph for hour 1948 saved to 3ed_tes_h_graphs/test_graph_hour_1948.gpickle
# Hour 1949:
# Label
# 0    20
# Name: count, dtype: int64
# Test graph for hour 1949 saved to 3ed_tes_h_graphs/test_graph_hour_1949.gpickle
# Hour 1950:
# Label
# 0    20
# Name: count, dtype: int64
# Test graph for hour 1950 saved to 3ed_tes_h_graphs/test_graph_hour_1950.gpickle
# Hour 1951:
# Label
# 0    39
# Name: count, dtype: int64
# Test graph for hour 1951 saved to 3ed_tes_h_graphs/test_graph_hour_1951.gpickle
# Hour 1952:
# Label
# 0    49
# Name: count, dtype: int64
# Test graph for hour 1952 saved to 3ed_tes_h_graphs/test_graph_hour_1952.gpickle
# Hour 1953:
# Label
# 0    45
# Name: count, dtype: int64
# Test graph for hour 1953 saved to 3ed_tes_h_graphs/test_graph_hour_1953.gpickle
# Hour 1954:
# Label
# 0    53
# Name: count, dtype: int64
# Test graph for hour 1954 saved to 3ed_tes_h_graphs/test_graph_hour_1954.gpickle
# Hour 1955:
# Label
# 0    51
# Name: count, dtype: int64
# Test graph for hour 1955 saved to 3ed_tes_h_graphs/test_graph_hour_1955.gpickle
# Hour 1956:
# Label
# 0    62
# Name: count, dtype: int64
# Test graph for hour 1956 saved to 3ed_tes_h_graphs/test_graph_hour_1956.gpickle
# Hour 1957:
# Label
# 0    54
# Name: count, dtype: int64
# Test graph for hour 1957 saved to 3ed_tes_h_graphs/test_graph_hour_1957.gpickle
# Hour 1958:
# Label
# 0    53
# Name: count, dtype: int64
# Test graph for hour 1958 saved to 3ed_tes_h_graphs/test_graph_hour_1958.gpickle
# Hour 1959:
# Label
# 0    76
# Name: count, dtype: int64
# Test graph for hour 1959 saved to 3ed_tes_h_graphs/test_graph_hour_1959.gpickle
# Hour 1960:
# Label
# 0    88
# Name: count, dtype: int64
# Test graph for hour 1960 saved to 3ed_tes_h_graphs/test_graph_hour_1960.gpickle
# Hour 1961:
# Label
# 0    51
# Name: count, dtype: int64
# Test graph for hour 1961 saved to 3ed_tes_h_graphs/test_graph_hour_1961.gpickle
# Hour 1962:
# Label
# 1    1003
# 0     154
# Name: count, dtype: int64
# Test graph for hour 1962 saved to 3ed_tes_h_graphs/test_graph_hour_1962.gpickle
# Hour 1963:
# Label
# 1    14804
# 0     6315
# Name: count, dtype: int64
# Test graph for hour 1963 saved to 3ed_tes_h_graphs/test_graph_hour_1963.gpickle
# Hour 1964:
# Label
# 1    14288
# 0    11617
# Name: count, dtype: int64
# Test graph for hour 1964 saved to 3ed_tes_h_graphs/test_graph_hour_1964.gpickle
# Hour 1965:
# Label
# 1    14050
# 0     8537
# Name: count, dtype: int64
# Test graph for hour 1965 saved to 3ed_tes_h_graphs/test_graph_hour_1965.gpickle
# Hour 1966:
# Label
# 1    14324
# 0     9107
# Name: count, dtype: int64
# Test graph for hour 1966 saved to 3ed_tes_h_graphs/test_graph_hour_1966.gpickle
# Hour 1967:
# Label
# 1    15443
# 0     8637
# Name: count, dtype: int64
# Test graph for hour 1967 saved to 3ed_tes_h_graphs/test_graph_hour_1967.gpickle
# Hour 1968:
# Label
# 1    14870
# 0     9287
# Name: count, dtype: int64
# Test graph for hour 1968 saved to 3ed_tes_h_graphs/test_graph_hour_1968.gpickle
# Hour 1969:
# Label
# 1    14837
# 0     9098
# Name: count, dtype: int64
# Test graph for hour 1969 saved to 3ed_tes_h_graphs/test_graph_hour_1969.gpickle
# Hour 1970:
# Label
# 1    8459
# 0    6720
# Name: count, dtype: int64
# Test graph for hour 1970 saved to 3ed_tes_h_graphs/test_graph_hour_1970.gpickle
# Hour 1985:
# Label
# 0    73
# Name: count, dtype: int64
# Test graph for hour 1985 saved to 3ed_tes_h_graphs/test_graph_hour_1985.gpickle
# Hour 1986:
# Label
# 0    438
# 1     70
# Name: count, dtype: int64
# Test graph for hour 1986 saved to 3ed_tes_h_graphs/test_graph_hour_1986.gpickle
# Hour 1987:
# Label
# 0    3069
# 1     131
# Name: count, dtype: int64
# Test graph for hour 1987 saved to 3ed_tes_h_graphs/test_graph_hour_1987.gpickle
# Hour 1988:
# Label
# 0    155
# Name: count, dtype: int64
# Test graph for hour 1988 saved to 3ed_tes_h_graphs/test_graph_hour_1988.gpickle
# Hour 1989:
# Label
# 0    445
# 1     18
# Name: count, dtype: int64
# Test graph for hour 1989 saved to 3ed_tes_h_graphs/test_graph_hour_1989.gpickle
# Hour 1990:
# Label
# 0    228
# 1     27
# Name: count, dtype: int64
# Test graph for hour 1990 saved to 3ed_tes_h_graphs/test_graph_hour_1990.gpickle
# Hour 1991:
# Label
# 0    217
# 1     40
# Name: count, dtype: int64
# Test graph for hour 1991 saved to 3ed_tes_h_graphs/test_graph_hour_1991.gpickle
# Hour 1992:
# Label
# 0    199
# 1     38
# Name: count, dtype: int64
# Test graph for hour 1992 saved to 3ed_tes_h_graphs/test_graph_hour_1992.gpickle
# Hour 1993:
# Label
# 0    98
# 1    22
# Name: count, dtype: int64
# Test graph for hour 1993 saved to 3ed_tes_h_graphs/test_graph_hour_1993.gpickle
# Hour 1994:
# Label
# 0    68
# 1    38
# Name: count, dtype: int64
# Test graph for hour 1994 saved to 3ed_tes_h_graphs/test_graph_hour_1994.gpickle
# Hour 1995:
# Label
# 0    84
# 1    30
# Name: count, dtype: int64
# Test graph for hour 1995 saved to 3ed_tes_h_graphs/test_graph_hour_1995.gpickle
# Hour 1996:
# Label
# 0    68
# 1    30
# Name: count, dtype: int64
# Test graph for hour 1996 saved to 3ed_tes_h_graphs/test_graph_hour_1996.gpickle
# Hour 1997:
# Label
# 0    69
# 1    32
# Name: count, dtype: int64
# Test graph for hour 1997 saved to 3ed_tes_h_graphs/test_graph_hour_1997.gpickle
# Hour 1998:
# Label
# 0    83
# 1    31
# Name: count, dtype: int64
# Test graph for hour 1998 saved to 3ed_tes_h_graphs/test_graph_hour_1998.gpickle
# Hour 1999:
# Label
# 0    70
# 1    24
# Name: count, dtype: int64
# Test graph for hour 1999 saved to 3ed_tes_h_graphs/test_graph_hour_1999.gpickle
# Hour 2000:
# Label
# 0    74
# 1    25
# Name: count, dtype: int64
# Test graph for hour 2000 saved to 3ed_tes_h_graphs/test_graph_hour_2000.gpickle
# Hour 2001:
# Label
# 0    98
# 1    39
# Name: count, dtype: int64
# Test graph for hour 2001 saved to 3ed_tes_h_graphs/test_graph_hour_2001.gpickle
# Hour 2002:
# Label
# 0    72
# 1    52
# Name: count, dtype: int64
# Test graph for hour 2002 saved to 3ed_tes_h_graphs/test_graph_hour_2002.gpickle
# Hour 2003:
# Label
# 0    51
# 1    51
# Name: count, dtype: int64
# Test graph for hour 2003 saved to 3ed_tes_h_graphs/test_graph_hour_2003.gpickle
# Hour 2004:
# Label
# 0    74
# 1    51
# Name: count, dtype: int64
# Test graph for hour 2004 saved to 3ed_tes_h_graphs/test_graph_hour_2004.gpickle
# Hour 2005:
# Label
# 0    65
# 1    55
# Name: count, dtype: int64
# Test graph for hour 2005 saved to 3ed_tes_h_graphs/test_graph_hour_2005.gpickle
# Hour 2006:
# Label
# 0    59
# 1    56
# Name: count, dtype: int64
# Test graph for hour 2006 saved to 3ed_tes_h_graphs/test_graph_hour_2006.gpickle
# Hour 2007:
# Label
# 0    65
# 1    56
# Name: count, dtype: int64
# Test graph for hour 2007 saved to 3ed_tes_h_graphs/test_graph_hour_2007.gpickle
# Hour 2008:
# Label
# 0    60
# 1    51
# Name: count, dtype: int64
# Test graph for hour 2008 saved to 3ed_tes_h_graphs/test_graph_hour_2008.gpickle
# Hour 2009:
# Label
# 0    69
# 1    57
# Name: count, dtype: int64
# Test graph for hour 2009 saved to 3ed_tes_h_graphs/test_graph_hour_2009.gpickle
# Hour 2010:
# Label
# 0    64
# 1    58
# Name: count, dtype: int64
# Test graph for hour 2010 saved to 3ed_tes_h_graphs/test_graph_hour_2010.gpickle
# Hour 2011:
# Label
# 0    68
# 1    64
# Name: count, dtype: int64
# Test graph for hour 2011 saved to 3ed_tes_h_graphs/test_graph_hour_2011.gpickle
# Hour 2012:
# Label
# 0    76
# 1    61
# Name: count, dtype: int64
# Test graph for hour 2012 saved to 3ed_tes_h_graphs/test_graph_hour_2012.gpickle
# Hour 2013:
# Label
# 0    55
# 1    47
# Name: count, dtype: int64
# Test graph for hour 2013 saved to 3ed_tes_h_graphs/test_graph_hour_2013.gpickle
# Hour 2014:
# Label
# 0    76
# 1    58
# Name: count, dtype: int64
# Test graph for hour 2014 saved to 3ed_tes_h_graphs/test_graph_hour_2014.gpickle
# Hour 2015:
# Label
# 0    79
# 1    26
# Name: count, dtype: int64
# Test graph for hour 2015 saved to 3ed_tes_h_graphs/test_graph_hour_2015.gpickle
# Hour 2018:
# Label
# 0    3301
# 1      23
# Name: count, dtype: int64
# Test graph for hour 2018 saved to 3ed_tes_h_graphs/test_graph_hour_2018.gpickle
# Hour 2019:
# Label
# 0    101
# 1     18
# Name: count, dtype: int64
# Test graph for hour 2019 saved to 3ed_tes_h_graphs/test_graph_hour_2019.gpickle
# Hour 2020:
# Label
# 0    11603
# 1        4
# Name: count, dtype: int64
# Test graph for hour 2020 saved to 3ed_tes_h_graphs/test_graph_hour_2020.gpickle

# %% [markdown]
# # Community detection for graphs and then update the graph with the label of community for each node

# %%
import networkx as nx
import os

def detect_and_label_communities_lpa(graph):
    """
    Perform community detection using the Label Propagation Algorithm (LPA) and label nodes with community IDs.
    Adds 'x' attribute based on the 'community' label.

    Parameters:
        graph (nx.MultiDiGraph): Input graph.

    Returns:
        graph (nx.MultiDiGraph): Updated graph with community labels and 'x' attributes.
    """
    # Convert MultiDiGraph to Graph (undirected graph for LPA)
    undirected_graph = nx.Graph(graph)

    # Perform community detection using LPA
    communities = nx.community.label_propagation_communities(undirected_graph)

    # Assign community labels to nodes and add 'x' attribute
    for community_id, community in enumerate(communities):
        for node in community:
            graph.nodes[node]['community'] = community_id
            graph.nodes[node]['x'] = [community_id]  # 'x' is a feature; wrap in a list for PyTorch Geometric compatibility

    return graph


def process_graphs_with_lpa(input_dir, output_dir):
    """
    Detect communities using LPA, update graphs with community labels, and add 'x' attribute.
    
    Parameters:
        input_dir (str): Directory containing input graphs.
        output_dir (str): Directory to save updated graphs.
    """
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Process each graph file in the input directory
    for graph_file in os.listdir(input_dir):
        if not graph_file.endswith('.gpickle'):
            continue
        
        # Load the graph
        graph_path = os.path.join(input_dir, graph_file)
        G = nx.read_gpickle(graph_path)

        # Detect communities using LPA and label nodes
        G = detect_and_label_communities_lpa(G)

        # Save the updated graph
        updated_graph_path = os.path.join(output_dir, graph_file)
        nx.write_gpickle(G, updated_graph_path)
        print(f"Updated graph with LPA communities and 'x' attribute saved to {updated_graph_path}")


# Example usage
if __name__ == "__main__":
    # Input directory containing graphs
    input_graph_dir = "3ed_tes_h_graphs"

    # Output directory for updated graphs
    output_graph_dir = "3ed_tes_h_graphs_commun"

    # Process graphs and add community labels using LPA
    process_graphs_with_lpa(input_graph_dir, output_graph_dir)
# Out:
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1961.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_656.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1995.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1985.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2000.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2010.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_670.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1397.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1968.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2019.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2009.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1935.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1925.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1957.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1947.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1886.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1969.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_671.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1412.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1402.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1924.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1934.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2008.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2018.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1887.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1956.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1960.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1970.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1912.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_657.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1994.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2011.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2001.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1400.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1410.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_673.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1909.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1919.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1895.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1885.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1954.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1936.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1926.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1910.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1878.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1962.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2003.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2013.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1996.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1986.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_655.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1879.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1911.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1963.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2012.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2002.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1987.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1997.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_654.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_672.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1411.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1401.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1918.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1908.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1955.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1884.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1894.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1927.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1937.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1950.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1940.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_658.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1891.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1881.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1932.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1404.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1875.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_3.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1992.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2007.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1949.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1959.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1888.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1904.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1399.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1966.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1993.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2006.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1889.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1958.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1948.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1905.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1398.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1967.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1880.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1890.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1941.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1951.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1933.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1405.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2020.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1874.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_652.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1928.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1938.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2004.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2014.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1991.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1965.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1917.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1907.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1931.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1988.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1998.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1892.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1882.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1953.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_0.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1876.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_674.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1407.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1999.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1989.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1920.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1930.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1952.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1883.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1893.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1877.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1406.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_675.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_653.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2015.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_2005.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1990.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1939.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1929.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1964.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1906.gpickle
# Updated graph with LPA communities and 'x' attribute saved to 3ed_tes_h_graphs_commun/test_graph_hour_1916.gpickle

# %% [markdown]
# # convert Multigraph to hetrodata

# %%
import torch
from torch_geometric.data import HeteroData
import networkx as nx
import os

def multiDiGraph_to_hetero_with_label(G: nx.MultiDiGraph) -> HeteroData:
    """
    Converts a MultiDiGraph with multiple edge types to a HeteroData object.
    Preserves the 'label' field in data[rel_type].edge_label.
    """
    data = HeteroData()
    node_mapping = {node: i for i, node in enumerate(G.nodes())}
    data['ip'].num_nodes = G.number_of_nodes()

    # Add node-level features
    x = []
    community_labels = []
    for node in G.nodes():
        community = G.nodes[node].get('community', -1)
        community_labels.append(community)
        x.append([community])
    data['ip'].community = torch.tensor(community_labels, dtype=torch.long)
    data['ip'].x = torch.tensor(x, dtype=torch.float)

    # Process each edge from G.
    for u, v, key, edge_attrs in G.edges(data=True, keys=True):
        src = node_mapping[u]
        dst = node_mapping[v]
        rel_type = ('ip', key, 'ip')
        
        if rel_type not in data.edge_types:
            data[rel_type].edge_index = []
            data[rel_type].edge_attr = []
            data[rel_type].edge_label = []  # Container for the label

        data[rel_type].edge_index.append([src, dst])
        
        # ---> FIX: Extract the label and append it <---
        edge_lbl = edge_attrs.get('label', 0) 
        data[rel_type].edge_label.append(edge_lbl)

        feature_vec = []
        
        # Append corresponding features from edge_attrs
        if key == 'network':
            for attr_name in network_features:
                feature_vec.append(edge_attrs.get(attr_name, 0.0))
        elif key == 'context':
            for attr_name in context_features:
                feature_vec.append(edge_attrs.get(attr_name, 0.0))
        elif key == 'knowledge':
            for attr_name in knowledge_features:
                feature_vec.append(edge_attrs.get(attr_name, 0.0))
                
        data[rel_type].edge_attr.append(feature_vec)

    # Convert lists to tensors.
    for rel_type in data.edge_types:
        data[rel_type].edge_index = torch.tensor(data[rel_type].edge_index, dtype=torch.long).t().contiguous()
        if data[rel_type].edge_attr:
            data[rel_type].edge_attr = torch.tensor(data[rel_type].edge_attr, dtype=torch.float)
        if data[rel_type].edge_label:
            # Save as a standard flat tensor
            data[rel_type].edge_label = torch.tensor(data[rel_type].edge_label, dtype=torch.long)
            
    return data

def process_and_save_hetero_graphs_with_label(input_dir, output_dir):
    """
    Converts all .gpickle graphs in a directory to HeteroData objects and saves them as .pt,
    preserving the 'label' field in data[rel_type].edge_label.
    """
    os.makedirs(output_dir, exist_ok=True)
    for graph_file in os.listdir(input_dir):
        if not graph_file.endswith('.gpickle'):
            continue
        graph_path = os.path.join(input_dir, graph_file)
        G = nx.read_gpickle(graph_path)
        hetero_data = multiDiGraph_to_hetero_with_label(G)
        hetero_path = os.path.join(output_dir, graph_file.replace('.gpickle', '.pt'))
        torch.save(hetero_data, hetero_path)
        print(f"Saved HeteroData with labels to {hetero_path}")

if __name__ == "__main__":
    input_test_dir = "3ed_tes_h_graphs_commun"         # Input .gpickle files (with communities added)
    output_test_pt_dir = "3ed_tes_h_graphs_hetero_graphs" # Output .pt files
    process_and_save_hetero_graphs_with_label(input_test_dir, output_test_pt_dir)
# Out:
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1961.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_656.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1995.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1985.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2000.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2010.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_670.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1397.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1968.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2019.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2009.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1935.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1925.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1957.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1947.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1886.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1969.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_671.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1412.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1402.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1924.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1934.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2008.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2018.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1887.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1956.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1960.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1970.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1912.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_657.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1994.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2011.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2001.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1400.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1410.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_673.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1909.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1919.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1895.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1885.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1954.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1936.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1926.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1910.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1878.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1962.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2003.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2013.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1996.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1986.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_655.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1879.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1911.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1963.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2012.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2002.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1987.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1997.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_654.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_672.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1411.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1401.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1918.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1908.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1955.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1884.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1894.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1927.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1937.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1950.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1940.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_658.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1891.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1881.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1932.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1404.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1875.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_3.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1992.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2007.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1949.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1959.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1888.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1904.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1399.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1966.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1993.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2006.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1889.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1958.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1948.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1905.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1398.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1967.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1880.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1890.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1941.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1951.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1933.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1405.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2020.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1874.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_652.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1928.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1938.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2004.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2014.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1991.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1965.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1917.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1907.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1931.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1988.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1998.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1892.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1882.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1953.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_0.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1876.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_674.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1407.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1999.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1989.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1920.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1930.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1952.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1883.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1893.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1877.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1406.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_675.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_653.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2015.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_2005.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1990.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1939.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1929.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1964.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1906.pt
# Saved HeteroData with labels to 3ed_tes_h_graphs_hetero_graphs/test_graph_hour_1916.pt
